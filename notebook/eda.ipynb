# %%
import pickle
artifact = pickle.load(open("../model/model.pkl", "rb"))
artifact["model"].coef_        # os pesos aprendidos pelo modelo
artifact["model"].intercept_   # o intercepto
artifact["scaler"].mean_       # a média usada na normalização
# Out:
# array([1.51343171e+00, 3.96879622e+02, 3.99182747e+00, 2.63017594e-01,
#        6.46235339e-01])

# %%
import sys
from pathlib import Path

sys.path.insert(0, str(Path.cwd().parent))

from app.service_completo import Recomendador, MODEL_PATH

r = Recomendador(MODEL_PATH)

print(r.is_known_user("u_0100"))
print(r.is_known_user("nao_existe_123"))
r.recommend("u_0100")   # em notebook, isso ja mostra a tabela sozinho, sem precisar de print
# Out:
# True
# False
# c:\Users\etest\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2684: UserWarning: X has feature names, but StandardScaler was fitted without feature names
#   warnings.warn(
#            product_id category  interactions   price  avg_rating  \
# product_id
# p_023           p_023     casa             4  298.27         3.2
# p_051           p_051     casa             3  576.33         3.5
# p_018           p_018     casa             2   55.28         4.8
# p_054           p_054     casa             2  621.35         5.0
# p_052           p_052     casa             2  613.41         3.3
# p_009           p_009   livros             2  164.19         3.2
# p_012           p_012     moda             2  752.81         4.9
# p_056           p_056     casa             1  427.73         4.3
# p_046           p_046     casa             1  589.09         4.2
# p_014           p_014     casa             1  486.36         4.3
#
# ...
